# %% [markdown]
# ### Jacobian Determinant

# %%
import os
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
from   natsort import natsorted

# %%
# Function to get the Jacobian determinat files
def get_file_paths(directory):
    file_types = {
        'jdet.nii.gz': []
    }
    
    for filename in os.listdir(directory):
        for file_suffix in file_types:
            if filename.endswith(file_suffix):
                file_types[file_suffix].append(os.path.join(directory, filename))
                break
    for key in file_types:
        file_types[key] = natsorted(file_types[key])
    
    return file_types

# %%
def load_nifti_image(file_path):
    nii   = nib.load(file_path)
    image = nii.get_fdata()
    return image, nii.affine

# %%
# Function to visualize a 3D image with consistent color scale
def visualize_jacobian(jacobian_data, color_range=(0, 2), cmap='jet'):
    # Plot slices from the 3D data
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    
    # Select slices (middle slice in each dimension)
    slice_x =  np.transpose(jacobian_data[jacobian_data.shape[0] // 3, :, :], (1, 0))
    slice_y =  np.transpose(jacobian_data[:, jacobian_data.shape[1] // 3, :], (1, 0))
    slice_z =  np.transpose(jacobian_data[:, :, jacobian_data.shape[2] // 3], (1, 0))

    slices = [slice_x, slice_y, slice_z]
    #titles = ['Sagittal Slice', 'Coronal Slice', 'Axial Slice']

    for i, ax in enumerate(axes):
        im = ax.imshow(slices[i], cmap=cmap, origin='lower',
                       vmin=color_range[0], vmax=color_range[1])
        ax.set_title(titles[i])
        fig.colorbar(im, ax=ax)

    plt.show()

# %% [markdown]
# ##### VoxelMorph

# %%
# VoxelMorph Directory
vxm_directory = '/data/groups/beets-tan/l.estacio/Med_Align_Net/Jul31-053533_Abtrain_VXMx1___/'
vxm_jdet_dir  = vxm_directory + 'jdet_figures/'
image_paths   = get_file_paths(vxm_directory)
jdet_paths    = image_paths['jdet.nii.gz']
jdet_0_path   = jdet_paths[0]
jdet_54_path  = jdet_paths[54]
print('len: ', len(jdet_paths))
#img2_paths    = get_file_paths['img2.nii.gz']
#img2_0_path   = img2_paths[0]
# Out:
# len:  55

# %%
color_range = (0, 2)
img, _ = load_nifti_image(jdet_0_path)
print(img.shape, ' min: ', img.min(), ' max: ', img.max())
visualize_jacobian(img, color_range=color_range, cmap='cividis')

color_range        = (0, 2)
img, _ = load_nifti_image(jdet_54_path)
print(img.shape, ' min: ', img.min(), ' max: ', img.max())
visualize_jacobian(img, color_range=color_range)
# Out:
# (192, 160, 256)  min:  -18.018175259092526  max:  34.59282289626301
# (192, 160, 256)  min:  -13.394529458566046  max:  16.94137151815938

# %% [markdown]
# ##### VTN

# %%
# VoxelMorph Directory
vtn_directory = '/data/groups/beets-tan/l.estacio/Med_Align_Net/Aug06-211340_Abtrain_VTNx3___/'
vtn_jdet_dir  = vtn_directory + 'jdet_figures/'
image_paths   = get_file_paths(vtn_directory)
jdet_paths    = image_paths['jdet.nii.gz']
jdet_0_path   = jdet_paths[0]
jdet_54_path  = jdet_paths[54]
print('len: ', len(jdet_paths))
# Out:
# len:  55

# %%
color_range = (0, 2)
img, _ = load_nifti_image(jdet_0_path)
print(img.shape, ' min: ', img.min(), ' max: ', img.max())
visualize_jacobian(img, color_range=color_range, cmap='cividis')

color_range        = (0, 2)
img, _ = load_nifti_image(jdet_54_path)
print(img.shape, ' min: ', img.min(), ' max: ', img.max())
visualize_jacobian(img, color_range=color_range)
# Out:
# (192, 160, 256)  min:  -50.2374901087412  max:  73.89386228434043
# (192, 160, 256)  min:  -24.096037932237927  max:  31.59495097853748

# %% [markdown]
# ##### TSM

# %%
# TSM Directory
tsm_directory = '/data/groups/beets-tan/l.estacio/Med_Align_Net/Aug07-042242_Abtrain_TSMx1___/'
tsm_jdet_dir  = tsm_directory + 'jdet_figures/'
image_paths   = get_file_paths(tsm_directory)
jdet_paths    = image_paths['jdet.nii.gz']
jdet_0_path   = jdet_paths[0]
jdet_54_path  = jdet_paths[54]
print('len: ', len(jdet_paths))
# Out:
# len:  55

# %%
color_range = (0, 2)
img, _ = load_nifti_image(jdet_0_path)
print(img.shape, ' min: ', img.min(), ' max: ', img.max())
visualize_jacobian(img, color_range=color_range, cmap='cividis')

color_range        = (0, 2)
img, _ = load_nifti_image(jdet_54_path)
print(img.shape, ' min: ', img.min(), ' max: ', img.max())
visualize_jacobian(img, color_range=color_range)
# Out:
# (192, 160, 256)  min:  -56.4988891881155  max:  155.46814505900429
# (192, 160, 256)  min:  -52.630377138901764  max:  65.99646962777851

# %% [markdown]
# #### CLM

# %%
CLM_directory = '/data/groups/beets-tan/l.estacio/Med_Align_Net/Aug12-033920_Abtrain_CLMx1___/'
CLM_jdet_dir  = CLM_directory + 'jdet_figures/'
image_paths   = get_file_paths(CLM_directory)
jdet_paths    = image_paths['jdet.nii.gz']
jdet_0_path   = jdet_paths[0]
jdet_54_path  = jdet_paths[54]
print('len: ', len(jdet_paths))
# Out:
# len:  55

# %%
color_range = (0, 2)
img, _ = load_nifti_image(jdet_0_path)
print(img.shape, ' min: ', img.min(), ' max: ', img.max())
visualize_jacobian(img, color_range=color_range, cmap='cividis')

color_range        = (0, 2)
img, _ = load_nifti_image(jdet_54_path)
print(img.shape, ' min: ', img.min(), ' max: ', img.max())
visualize_jacobian(img, color_range=color_range)
# Out:
# (192, 160, 256)  min:  -13.59838683927171  max:  51.40685672258742
# (192, 160, 256)  min:  -8.470939883237655  max:  10.79042156575677

# %% [markdown]
# ##### ELASTIX

# %%
# Elastix Directory
elx_directory = '/data/groups/beets-tan/l.estacio/Med_Align_Net/elastix_Abd/'
elx_jdet_dir  = elx_directory + 'jdet_figures/'
image_paths   = get_file_paths(elx_directory)
jdet_paths    = image_paths['jdet.nii.gz']
jdet_0_path   = jdet_paths[0]
jdet_54_path  = jdet_paths[54]
print('len: ', len(jdet_paths))
# Out:
# len:  55

# %%
color_range = (0, 2)
img, _ = load_nifti_image(jdet_0_path)
print(img.shape, ' min: ', img.min(), ' max: ', img.max())
visualize_jacobian(img, color_range=color_range, cmap='cividis')

color_range        = (0, 2)
img, _ = load_nifti_image(jdet_54_path)
print(img.shape, ' min: ', img.min(), ' max: ', img.max())
visualize_jacobian(img, color_range=color_range)
# Out:
# (192, 160, 256)  min:  -2.310268741337838  max:  1.943774481431357
# (192, 160, 256)  min:  -0.6273789235444547  max:  0.806205902833011

# %% [markdown]
# ##### ANTs

# %%
# ANTs Directory
ant_directory = '/data/groups/beets-tan/l.estacio/Med_Align_Net/ants_Abd/'
ant_jdet_dir  = ant_directory + 'jdet_figures/'
image_paths   = get_file_paths(ant_directory)
jdet_paths    = image_paths['jdet.nii.gz']
jdet_0_path   = jdet_paths[0]
jdet_54_path  = jdet_paths[54]
print('len: ', len(jdet_paths))
# Out:
# len:  55

# %%
color_range = (0, 2)
img, _ = load_nifti_image(jdet_0_path)
print(img.shape, ' min: ', img.min(), ' max: ', img.max())
visualize_jacobian(img, color_range=color_range, cmap='cividis')

color_range        = (0, 2)
img, _ = load_nifti_image(jdet_54_path)
print(img.shape, ' min: ', img.min(), ' max: ', img.max())
visualize_jacobian(img, color_range=color_range)
# Out:
# (192, 160, 256)  min:  -0.22781821607685518  max:  0.3386521635629683
# (192, 160, 256)  min:  -0.06271065116493292  max:  0.1194340374314667
